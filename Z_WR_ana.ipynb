# %%
from Eval_WR_ana import *
#system_name="again_try_resid_lr001_scal20_500"
#system_name="again_try_resid_lr001_scal20_300_shift001"

#system_name="again_try_resid_lr001_scal50_300"
system_name="again_try_resid_lr001_scal20_500_shift001"
dnwp1=os.path.join("/mnt/data_disk2/n_workspace/RL/",system_name,"Classifiaction","WR","EvalAgent_4")
ETs=[int(fn[2:-4]) for fn in os.listdir(dnwp1)]
ETs.sort()
print ("ET","RBW","RBR","RBRZ","RB/A","CBuy", "ET","P25P","P50P","P75P","TotalP" )
for ET in ETs:
    dfWR=ET_WR_detial(system_name, ET)
    dfPA=ET_PA_detial(system_name, ET)
    print ("")
# Out:
# ET RBW RBR RBRZ RB/A CBuy ET P25P P50P P75P TotalP
# 250 0.50 0.47 0.50 0.21 20146 250 -0.01 0.00 0.01 -24.56
# 500 0.50 0.47 0.50 0.20 18273 500 -0.01 0.00 0.01 -19.79
# 750 0.50 0.47 0.50 0.17 16005 750 -0.01 0.00 0.01 -24.01
# 1000 0.49 0.48 0.51 0.15 14401 1000 -0.01 0.00 0.01 -12.19
# 1250 0.50 0.47 0.50 0.13 12238 1250 -0.01 -0.00 0.01 -15.60
# 1500 0.49 0.47 0.51 0.11 10391 1500 -0.01 0.00 0.01 -12.99
# 1750 0.48 0.49 0.52 0.10 9355 1750 -0.01 -0.00 0.01 -3.82
# 2000 0.48 0.49 0.52 0.09 8699 2000 -0.01 0.00 0.01 -1.31
# 2250 0.47 0.50 0.53 0.09 8002 2250 -0.01 0.00 0.01 2.21
# 2500 0.45 0.51 0.55 0.08 7387 2500 -0.01 0.00 0.01 7.15
# 2750 0.43 0.54 0.57 0.07 6558 2750 -0.01 0.00 0.02 17.51
# 3000 0.40 0.57 0.60 0.07 6207 3000 -0.01 0.00 0.02 25.65
# 3250 0.38 0.59 0.62 0.06 5656 3250 -0.01 0.01 0.02 33.31
# 3500 0.36 0.62 0.64 0.06 5382 3500 -0.01 0.01 0.02 42.24
# 3750 0.33 0.64 0.67 0.06 5468 3750 -0.01 0.01 0.03 52.59
# ...
