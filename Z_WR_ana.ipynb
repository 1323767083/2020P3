# %%
from Eval_WR_ana import *
system_name="again_try_resid_lr001_scal20_300"
dnwp1=os.path.join("/mnt/data_disk2/n_workspace/RL/",system_name,"Classifiaction","WR","EvalAgent_4")
ETs=[int(fn[2:-4]) for fn in os.listdir(dnwp1)]
ETs.sort()

for ET in ETs:
    dfWR=ET_WR_detial(system_name, ET)
    dfPA=ET_PA_detial(system_name, ET)
    print ("")
# Out:
# 250 0.50 0.47 0.50 0.23 10257 250 -0.01 0.00 0.01 -10.19
# 500 0.50 0.47 0.50 0.22 9745 500 -0.01 0.00 0.01 -13.11
# 750 0.50 0.47 0.50 0.21 9575 750 -0.01 0.00 0.01 -8.95
# 1000 0.50 0.47 0.50 0.20 9057 1000 -0.01 -0.00 0.01 -7.41
# 1250 0.50 0.47 0.50 0.20 8875 1250 -0.01 -0.00 0.01 -9.86
# 1500 0.48 0.49 0.52 0.20 8914 1500 -0.01 -0.00 0.01 -1.96
# 1750 0.47 0.49 0.53 0.19 8678 1750 -0.01 0.00 0.01 5.88
# 2000 0.46 0.51 0.54 0.20 9126 2000 -0.01 0.00 0.01 9.86
# 2250 0.42 0.54 0.58 0.20 8835 2250 -0.01 0.00 0.02 19.45
# 2500 0.41 0.56 0.59 0.21 9336 2500 -0.01 0.00 0.02 33.30
# 2750 0.39 0.58 0.61 0.18 8100 2750 -0.01 0.00 0.02 39.06
# 3000 0.40 0.57 0.60 0.19 8650 3000 -0.01 0.00 0.02 36.32
# 3250 0.39 0.58 0.61 0.17 7832 3250 -0.01 0.00 0.02 36.33
# 3500 0.41 0.56 0.59 0.18 7910 3500 -0.01 -0.00 0.02 33.70
# 3750 0.39 0.58 0.61 0.15 6576 3750 -0.01 0.00 0.02 34.17
# 4000 0.38 0.59 0.62 0.12 5365 4000 -0.01 -0.00 0.02 35.19
# ...
