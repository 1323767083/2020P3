# %%
from Agent_Trader_Mana import *

# %%
List_Strategies_Config("p2")
# Out:
#   Strategy                             RL_system_name  RL_Model_ET  GPU_idx  \
# 0       s1  again_try_resid_lr001_scal20_300_shift001        22500        0
# 1       s1  again_try_resid_lr001_scal20_300_shift001        22500        0
# 2       s2  again_try_resid_lr001_scal20_300_shift001        22500        0
#
#    GPU_mem   TPDB_Name  SL_Name SL_Tag  SL_Idx  \
# 0     4000  DBTP_10MV1  SL300V1   Eval       1
# 1     4000  DBTP_10MV1  SL300V1   Eval       1
# 2     4000  DBTP_10MV1  SL300V1   Eval       1
#
#                           strategy_fun
# 0  Buy_Strategy_multi_time_Direct_sell
# 1  Buy_Strategy_multi_time_Direct_sell
# 2  Buy_Strategy_multi_time_Direct_sell

# %%
a=ana_earning("p2","s1","eR2")

# %%
_,dfm=get_datas_for_experiment("p2","s1","eR1")
dfm
# Out:
#         CEarn  CLoss  CBalance  CToBuy  CToSell  CNotToBuy_due_limit  \
# MonthI
# 202012      4      0         0       4        4                    0
# 202101      0      1         0       1        1                    0
# 202102      1      1         0       2        2                    0
# 202103      2      0         0       2        2                    0
# 202104      0      0         0       0        0                    0
#
#         CMultibuy  CFailBuy  CFailSell  CTotal  REarn  RLoss  RBalance
# MonthI
# 202012          0         0          0       4   1.00   0.00      0.00
# 202101          0         0          0       1   0.00   1.00      0.00
# 202102          0         0          0       2   0.50   0.50      0.00
# 202103          0         0          0       2   1.00   0.00      0.00
# 202104          0         0          0       0   0.00   0.00      0.00

# %%
get_per_tran_result('p2', 's1', 'eR1')
# Out:
#       dateI  model     Stock   profit
# 0  20201209      0  SH601727  1473.67
# 1  20201209      1  SH601727  1958.99
# 2  20201216      0  SZ002508   720.53
# 3  20201216      1  SZ002508   925.38
# 4  20210113      1  SZ000066  -229.89
# 5  20210222      0  SZ002352   160.83
# 6  20210222      1  SZ002352  -491.04
# 7  20210326      0  SH601318   386.67
# 8  20210326      1  SH601318   129.01

# %%
get_tran_detail('p2', 's1', 'eR1', -300)
# Out:
# [20210219, 20210222, 1, 1, -491.04]
# (          TransIDI  Holding_Gu  Holding_Invest  Holding_HRatio  \
#  Stock
#  SH601216         0           0            0.00            1.00
#  SH601211         0           0            0.00            1.00
#  SH600369         0           0            0.00            1.00
#  SH601390         0           0            0.00            1.00
#  SH601225         0           0            0.00            1.00
#  ...            ...         ...             ...             ...
#  SH601212         0           0            0.00            1.00
#  SH601899         0           0            0.00            1.00
#  SZ002739         0           0            0.00            1.00
#  SH601688         0           0            0.00            1.00
#  SZ002594         0           0            0.00            1.00
#
#            Holding_NPrice  Buy_Times  HoldingStartDateI  AfterClosing_HFQRatio  \
#  Stock
# ...
