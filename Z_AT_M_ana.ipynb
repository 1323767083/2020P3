# %%
from Agent_Trader_Mana import *

# %%
List_Strategies_Config("p3")
# Out:
#   Strategy                             RL_system_name  RL_Model_ET  GPU_idx  \
# 0       s1  again_try_resid_lr001_scal20_300_shift001        22500        0
# 1       s1  again_try_resid_lr001_scal20_500_shift001        21750        1
# 2       s2  again_try_resid_lr001_scal20_300_shift001        22500        0
# 3       s2  again_try_resid_lr001_scal20_500_shift001        21750        1
#
#    GPU_mem   TPDB_Name  SL_Name
# 0     4000  DBTP_10MV1  SL300V1
# 1     4000  DBTP_10MV1  SL500V1
# 2     4000  DBTP_10MV1  SL300V1
# 3     4000  DBTP_10MV1  SL500V1

# %%
a=ana_earning("p3","s2","eFS_300")

# %%
_,dfm=get_datas_for_experiment("p3","s2","eFS_300")
dfm
# Out:
#         CEarn  CLoss  CBalance  CToBuy  CToSell  CNotToBuy_due_limit  \
# MonthI
# 201801      1      0         0      59        1                    0
# 201802      0      0         0      42        1                    0
# 201803      0      1         0      44        0                    0
# 201804      0      1         0      32        1                    0
# 201805      0      0         0      44        0                    0
# 201806      3      1         0      67        7                    0
# 201807      5      0         0     103        2                    0
# 201808      0      3         0      63        3                    0
# 201809      0      0         0      38        0                    0
# 201810     31      0         0      65       32                    4
# 201811      5      1         0      16       14                    0
# 201812     11      0         0       2        2                    0
# ...

# %%
df=get_per_tran_result('p3', 's2', 'eR_300500X4')
df
# Out:
#         dateI  model     Stock   profit
# 0    20201203      3  SH600745  1362.04
# 1    20201203      4  SZ002948  5448.76
# 2    20201203      5  SZ002948  5448.77
# 3    20201203      6  SZ002948  4987.37
# 4    20201203      7  SZ002948  5406.81
# ..        ...    ...       ...      ...
# 222  20210414      7  SH601005 -5192.32
# 223  20210419      4  SH600707  -807.03
# 224  20210419      5  SH600707   109.51
# 225  20210419      6  SH600707  -814.36
# 226  20210419      7  SH600707  -902.30
#
# [227 rows x 4 columns]

# %%
df=get_tran_detail('p3', 's1', 'eR3', 1000)
# Out:
# [20201202, 20201203, 2, 1, 5448.76]
# [20201202, 20201203, 3, 1, 5406.81]
# [20201202, 20201204, 3, 2, 2319.52]
# [20201217, 20201218, 3, 1, 2110.93]
# [20201221, 20201222, 2, 1, 5872.07]
# [20210106, 20210107, 2, 1, 4138.84]
# [20210107, 20210108, 2, 1, 2035.98]
# [20210107, 20210108, 3, 1, 6715.36]
# [20210118, 20210119, 1, 1, 1672.51]
# [20210120, 20210121, 2, 1, 1835.53]
# [20210120, 20210121, 3, 1, 1210.48]
# [20210222, 20210223, 3, 1, 1066.61]
# [20210224, 20210225, 3, 1, 2348.35]
# [20210303, 20210304, 0, 1, 1058.63]
# [20210303, 20210304, 2, 1, 2197.42]
# [20210303, 20210304, 3, 1, 2341.8]
# [20210305, 20210308, 2, 1, 1466.31]
# [20210305, 20210308, 3, 1, 2118.66]
# [20210305, 20210308, 3, 1, 1426.25]
# [20210312, 20210315, 2, 1, 1097.22]
# [20210312, 20210315, 3, 1, 1134.83]
# [20210322, 20210323, 2, 1, 1873.69]
# [20210322, 20210323, 2, 1, 4011.17]
# [20210322, 20210323, 3, 1, 1700.27]
# [20210322, 20210323, 3, 1, 3941.37]
# [20210324, 20210325, 2, 1, 1281.01]
# ...
